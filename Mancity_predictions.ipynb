# %%
import pandas as pd

# %%
mancity = pd.read_csv('mancity23-24.csv',index_col=0)

# %%
mancity.head()
# Out:
#          Date          Competition                Venue   H/A  goals for(gf)  \
# 1  06-08-2023  FA Community Shield      Wembley Stadium  away              1
# 2  12-08-2023       Premier League            Turf Moor  away              3
# 3  17-08-2023       UEFA Super Cup  Karaiskakis Stadium  away              1
# 4  20-08-2023       Premier League       Etihad Stadium  home              1
# 5  27-08-2023       Premier League         Bramall Lane  away              2
#
#    goals against(ga)     opponent(opp)  poss  poss for opp  shots  ...  \
# 1                  1           Arsenal    55            45      8  ...
# 2                  0           Burnley    66            34     17  ...
# 3                  1           Sevilla    74            26     23  ...
# 4                  0         Newcastle    59            41     14  ...
# 5                  1  Sheffield United    80            20     30  ...
#
#    fouls by opp  yellow  yellow for opp  red  red for opp  offsides  \
# ...

# %%
mancity.shape
# Out:
# (59, 28)

# %%
mancity["opponent(opp)"].value_counts()
# Out:
# opponent(opp)
# Newcastle              4
# Arsenal                3
# Manchester United      3
# Luton Town             3
# Tottenham              3
# Chelsea                3
# FC Copenhagen          2
# Brentford              2
# Everton                2
# Crystal Palace         2
# Aston Villa            2
# Liverpool              2
# Burnley                2
# Bournemouth            2
# Young Boys             2
# Brighton               2
# RB Leipzig             2
# Wolves                 2
# Nottingham Forest      2
# Crvena zvezda          2
# West Ham               2
# Fulham                 2
# Sheffield United       2
# Real Madrid            2
# Urawa Reds             1
# Fluminense             1
# Huddersfield United    1
# Sevilla                1
# Name: count, dtype: int64

# %%
mancity[mancity["opponent(opp)"] == "Liverpool"].sort_values("Date")
# Out:
#           Date     Competition           Venue   H/A  goals for(gf)  \
# 44  10-03-2024  Premier League         Anfield  away              1
# 20  25-11-2023  Premier League  Etihad Stadium  home              1
#
#     goals against(ga) opponent(opp)  poss  poss for opp  shots  ...  \
# 44                  1     Liverpool    47            53     10  ...
# 20                  1     Liverpool    60            40     16  ...
#
#     fouls by opp  yellow  yellow for opp  red  red for opp  offsides  \
# 44             6       3               0    0            0         1
# 20            11       1               3    0            0         3
#
#     offsides for opp  corners  corners for opp  Result
# 44                 6        4                7       D
# 20                 4        9                6       D
#
# [2 rows x 28 columns]

# %%
mancity["Competition"].value_counts()
# Out:
# Competition
# Premier League           39
# UEFA Champions League    10
# FA Cup                    5
# FIFA Club World Cup       2
# FA Community Shield       1
# UEFA Super Cup            1
# EFL Cup                   1
# Name: count, dtype: int64

# %%
mancity.dtypes
# Out:
# Date                       object
# Competition                object
# Venue                      object
# H/A                        object
# goals for(gf)               int64
# goals against(ga)           int64
# opponent(opp)              object
# poss                        int64
# poss for opp                int64
# shots                       int64
# shots at target             int64
# shots for opp               int64
# shots at target for opp     int64
# passes                      int64
# passes for opp              int64
# pass acc                    int64
# pass acc for opp            int64
# fouls                       int64
# fouls by opp                int64
# yellow                      int64
# yellow for opp              int64
# red                         int64
# red for opp                 int64
# offsides                    int64
# offsides for opp            int64
# corners                     int64
# corners for opp             int64
# ...

# %%
mancity
# Out:
#           Date            Competition                       Venue   H/A  \
# 1   06-08-2023    FA Community Shield             Wembley Stadium  away
# 2   12-08-2023         Premier League                   Turf Moor  away
# 3   17-08-2023         UEFA Super Cup         Karaiskakis Stadium  away
# 4   20-08-2023         Premier League              Etihad Stadium  home
# 5   27-08-2023         Premier League                Bramall Lane  away
# 6   02-09-2023         Premier League              Etihad Stadium  home
# 7   16-09-2023         Premier League              London Stadium  away
# 8   20-09-2023  UEFA Champions League              Etihad Stadium  home
# 9   23-09-2023         Premier League              Etihad Stadium  home
# 10  28-09-2023                EFL Cup              St. James Park  away
# 11  30-09-2023         Premier League            Molineux Stadium  away
# 12  05-10-2023  UEFA Champions League      Red Bull Arena Leipzig  away
# ...

# %%
mancity["target"] = (mancity["Result"] == "W").astype("int")

# %%
mancity
# Out:
#           Date            Competition                       Venue   H/A  \
# 1   06-08-2023    FA Community Shield             Wembley Stadium  away
# 2   12-08-2023         Premier League                   Turf Moor  away
# 3   17-08-2023         UEFA Super Cup         Karaiskakis Stadium  away
# 4   20-08-2023         Premier League              Etihad Stadium  home
# 5   27-08-2023         Premier League                Bramall Lane  away
# 6   02-09-2023         Premier League              Etihad Stadium  home
# 7   16-09-2023         Premier League              London Stadium  away
# 8   20-09-2023  UEFA Champions League              Etihad Stadium  home
# 9   23-09-2023         Premier League              Etihad Stadium  home
# 10  28-09-2023                EFL Cup              St. James Park  away
# 11  30-09-2023         Premier League            Molineux Stadium  away
# 12  05-10-2023  UEFA Champions League      Red Bull Arena Leipzig  away
# ...

# %%
mancity["poss"] = mancity["poss"].astype("int")

# %%
mancity["passes"] = mancity["passes"].astype("int")

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = mancity[mancity["Date"] < '4-11-2023']

# %%
test = mancity[mancity["Date"]>"4-11-2023"]

# %%
predictors = ["poss","passes"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(mancity, test_size=0.2, random_state=42)
print(test.shape)
# Out:
# (12, 29)

# %%
test = test.dropna()  # Might remove all rows if NaN values exist
test = test[test['Date'] > "04-11-23"]  # Might remove all rows if condition filters everything out

# %%
print(test.shape)
print(test.head())
# Out:
# (11, 29)
#           Date          Competition                    Venue   H/A  \
# 1   06-08-2023  FA Community Shield          Wembley Stadium  away
# 35  06-02-2024       Premier League  Gtech Community Stadium  away
# 14  21-10-2023       Premier League           Etihad Stadium  home
# 46  31-03-2024       Premier League           Etihad Stadium  home
# 54  28-04-2024       Premier League             City Stadium  away
#
#     goals for(gf)  goals against(ga)      opponent(opp)  poss  poss for opp  \
# 1               1                  1            Arsenal    55            45
# 35              3                  1          Brentford    72            28
# 14              2                  1           Brighton    55            45
# 46              0                  0            Arsenal    73            27
# 54              2                  0  Nottingham Forest    67            33
#
#     shots  ...  yellow  yellow for opp  red  red for opp  offsides  \
# ...

# %%
print(test[predictors].shape)
print(test[predictors].head())
# Out:
# (11, 2)
#     poss  passes
# 1     55     590
# 35    72     750
# 14    55     609
# 46    73     700
# 54    67     733

# %%
print(len(test))
print(test[predictors].dropna().shape)
# Out:
# 11
# (11, 2)

# %%
print(test[predictors].isna().sum())  # Check for missing values
# Out:
# poss      0
# passes    0
# dtype: int64

# %%
test[predictors] = test[predictors].apply(pd.to_numeric, errors='coerce')

# %%
preds = rf.predict(test[predictors].values)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
error = accuracy_score(test["target"], preds)

# %%
error
# Out:
# 0.9090909090909091

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted  0  1
# actual
# 0          3  1
# 1          0  7

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.875
